# %% [markdown]
# # Quantum Convolutional Neural Network

# %% [markdown]
# This is an implementation of 8 Qubit QCNN circuit testing various ansatze.

# %%
import pennylane as qml
from pennylane import numpy as np
np.random.seed(0)

# %% [markdown]
# # QCNN Circuit

# %% [markdown]
# Here are various unitary ansatze to test

# %%
def U_TTN(theta1, theta2, wires):
    qml.RY(theta1, wires = wires[0])
    qml.RY(theta2, wires = wires[1])
    qml.CNOT(wires = [wires[0], wires[1]])

def U_13(params, wires): # 6 params
    qml.RY(params[0], wires = wires[0])
    qml.RY(params[1], wires = wires[1])
    qml.CRZ(params[2], wires = [wires[1], wires[0]])
    qml.RY(params[3], wires = wires[0])
    qml.RY(params[4], wires = wires[1])
    qml.CRZ(params[5], wires = [wires[0], wires[1]])

def U_15(params, wires): # 4 params
    qml.RY(params[0], wires = wires[0])
    qml.RY(params[1], wires = wires[1])
    qml.CNOT(wires = [wires[1], wires[0]])
    qml.RY(params[2], wires = wires[0])
    qml.RY(params[3], wires = wires[1])
    qml.CNOT(wires = [wires[0], wires[1]])
    
def V_0(theta, wires):
    qml.CRZ(theta, wires = [wires[0], wires[1]])

def V_1(theta, wires):
    qml.CRX(theta, wires = [wires[0], wires[1]])

def F(wires):
    qml.CNOT(wires = [wires[0], wires[1]])

# %% [markdown]
# Define general layers that will be used in the circuits.

# %%
# Convolution Layer1
def conv_layer1(U, params):
    U(params, wires = [0,7])
    for i in range (0,8,2):
        U(params, wires = [i, i+1])
    for i in range (1,7,2):
        U(params, wires = [i, i+1])
    
def conv_layer2(U, params):
    U(params, wires = [0,2])
    U(params, wires = [4,6])
    U(params, wires = [2,4])
    U(params, wires = [0,6])
    
def pooling_layer1(V_0, V_1, params):
    for i in range(0,8,2):
        V_0(params[0], wires = [i+1, i])
    for i in range(0,8,2):
        qml.PauliX(wires = i+1)
    for i in range(0,8,2):
        V_1(params[1], wires = [i+1, i])
        

def pooling_layer2(V_0, V_1, params): # 2params
    V_0(params[0], wires = [2,0])
    V_0(params[0], wires = [6,4])
    
    qml.PauliX(wires = 2)
    qml.PauliX(wires = 6)
    
    V_1(params[1], wires = [2,0])
    V_1(params[1], wires = [6,4])

# %% [markdown]
# Here we define various possible embedding methods.

# %%
def data_embedding(X, embedding_type = 'Amplitude'):
    if embedding_type == 'Amplitude':
        AmplitudeEmbedding(X, wires = range(8), normalize = True)
    elif embedding_type == 'Angle':
        AngleEmbedding(X, wires = range(8))

# %%
params = np.random.randn(12)
param1 = [params[0:4]]
param2 = [params[4:8]]
param3 = [params[8:10]]
param4 = [params[10:12]]
print(params)
print(param1)
print(param2)
# Out:
# [-0.89666714  3.02354853 -0.60688682  1.80890493  0.68924386 -0.63138681
#  -1.65751229  1.06921624  0.10308946 -0.57081445 -0.65464158 -0.21715213]
# [tensor([-0.89666714,  3.02354853, -0.60688682,  1.80890493], requires_grad=True)]
# [tensor([ 0.68924386, -0.63138681, -1.65751229,  1.06921624], requires_grad=True)]

# %%
# Hyperparameters
U = U_15
U_params = 4
total_params = U_params * 2 + 2 * 2

# %%
from pennylane.templates.embeddings import AmplitudeEmbedding, AngleEmbedding


dev = qml.device('default.qubit', wires = 8)
@qml.qnode(dev)
def QCNN(X, params, U = U, embedding_type = 'Amplitude'):
    
    param1 = [params[0:U_params]]
    param2 = [params[U_params:2*U_params]]
    param3 = [params[2*U_params: 2*U_params + 2]]
    param4 = [params[2*U_params + 2: 2*U_params + 4]]

    data_embedding(X, embedding_type = embedding_type)
    
    conv_layer1(U, param1)
    pooling_layer1(V_0, V_1, param2)
    conv_layer2(U, param3)
    pooling_layer2(V_0, V_1, param4)
    
    F(wires = [0,4])
    return qml.expval(qml.PauliZ(4))

# %% [markdown]
# # Training Quantum Circuits

# %%
def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def cost(params, X, Y):
    predictions = [QCNN(x, params) for x in X]
    return square_loss(Y, predictions)

def accuracy(predictions, labels):
    acc = 0
    for l,p in zip(labels, predictions):
        if np.abs(l - p) < 0.5:
            acc = acc + 1
    return acc / len(labels)

# %%
def circuit_training(X_train, Y_train):
    params = np.random.randn(total_params)
    steps = 200
    learning_rate = 0.1
    batch_size =25
    opt = qml.NesterovMomentumOptimizer(learning_rate)
    
    for it in range(steps):
        batch_index = np.random.randint(0, len(X_train), (batch_size,))
        X_batch = [X_train[i] for i in batch_index]
        Y_batch = [Y_train[i] for i in batch_index]
        params, cost_new = opt.step_and_cost(lambda v: cost(v, X_batch, Y_batch), params)
        if it % 10 == 0:
            print("iteration: ", it, " cost: ", cost_new)
    return params

# %% [markdown]
# ### Results

# %% [markdown]
# Data Processing Procedure

# %%
import tensorflow as tf
def data_load_and_process(classes = [0,1]):
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
    x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0
    
    x_train_filter_01 = np.where((y_train == classes[0]) | (y_train == classes[1]))
    x_test_filter_01 = np.where((y_test == classes[0]) | (y_test == classes[1]))
    
    
    x_train_01 = x_train[x_train_filter_01]
    y_train_01 = y_train[x_train_filter_01]
    x_test_01 = x_test[x_test_filter_01]
    y_test_01 = y_test[x_test_filter_01]
    
    
    x_train= tf.cast(x_train_01, tf.float32)
    x_test=tf.cast(x_test_01, tf.float32)
    
    x_train = tf.image.resize(x_train[:], (256, 1)).numpy()
    x_test = tf.image.resize(x_test[:], (256, 1)).numpy()
    
    x_train, x_test = tf.squeeze(x_train), tf.squeeze(x_test)
    
    return x_train, x_test, y_train_01, y_test_01

# %%
x_train, x_test, y_train, y_test = data_load_and_process()

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 8)
pca.fit(x_train)
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)

# %% [markdown]
# Training QCNN with amplitdue encoding.

# %%
trained_params_amp = circuit_training(x_train, y_train)
# Out:
# iteration:  0  cost:  0.6516509151394178
# iteration:  10  cost:  0.11551695476619508
# iteration:  20  cost:  0.08705409549652122
# iteration:  30  cost:  0.03230764607467249
# iteration:  40  cost:  0.038195760856150715
# iteration:  50  cost:  0.05271543359043137
# iteration:  60  cost:  0.051772828004233974
# iteration:  70  cost:  0.06148899723118883
# iteration:  80  cost:  0.039396990852718694
# iteration:  90  cost:  0.03241109224240893
# iteration:  100  cost:  0.046324785743376534
# iteration:  110  cost:  0.045720752359008125
# iteration:  120  cost:  0.046850186882593396
# iteration:  130  cost:  0.029606568119009618
# iteration:  140  cost:  0.026877343178648684
# iteration:  150  cost:  0.05790818609053103
# iteration:  160  cost:  0.03305564810709723
# iteration:  170  cost:  0.043388537981140146
# iteration:  180  cost:  0.054404610460382495
# iteration:  190  cost:  0.04176706345731735

# %%
predictions = [QCNN(x, trained_params_amp) for x in x_test]
accuracy(predictions, y_test)
# Out:
# 0.9881796690307328

# %%
# Out:
# [tensor(0.84268859, requires_grad=True), tensor(0.14695876, requires_grad=True), tensor(0.87280198, requires_grad=True), tensor(-0.09250067, requires_grad=True), tensor(-0.15585305, requires_grad=True), tensor(0.84439012, requires_grad=True), tensor(0.16854859, requires_grad=True), tensor(0.01902671, requires_grad=True), tensor(0.8562634, requires_grad=True), tensor(0.7974725, requires_grad=True), tensor(0.87020639, requires_grad=True), tensor(0.84854269, requires_grad=True), tensor(0.74262162, requires_grad=True), tensor(0.87579295, requires_grad=True), tensor(0.04711971, requires_grad=True), tensor(0.82717032, requires_grad=True), tensor(-0.14327239, requires_grad=True), tensor(0.01228052, requires_grad=True), tensor(0.84172946, requires_grad=True), tensor(0.78251227, requires_grad=True), tensor(0.8252943, requires_grad=True), tensor(0.78941632, requires_grad=True), tensor(-0.12120385, requires_grad=True), tensor(0.65089868, requires_grad=True), tensor(0.06966746, requires_grad=True), tensor(0.83013947, requires_grad=True), tensor(-0.12205113, requires_grad=True), tensor(0.90289895, requires_grad=True), tensor(0.92465535, requires_grad=True), tensor(0.93013428, requires_grad=True), tensor(-0.04342722, requires_grad=True), tensor(0.65886165, requires_grad=True), tensor(0.01686357, requires_grad=True), tensor(0.83856743, requires_grad=True), tensor(0.89823464, requires_grad=True), tensor(0.81692354, requires_grad=True), tensor(0.78484271, requires_grad=True), tensor(-0.01523544, requires_grad=True), tensor(0.00163956, requires_grad=True), tensor(0.87792628, requires_grad=True), tensor(0.80446973, requires_grad=True), tensor(0.8331953, requires_grad=True), tensor(-0.08263841, requires_grad=True), tensor(-0.04384757, requires_grad=True), tensor(0.82703127, requires_grad=True), tensor(0.69672952, requires_grad=True), tensor(0.91381774, requires_grad=True), tensor(0.83462643, requires_grad=True), tensor(0.02184403, requires_grad=True), tensor(0.6162519, requires_grad=True), tensor(0.83314681, requires_grad=True), tensor(0.86173902, requires_grad=True), tensor(-0.01812153, requires_grad=True), tensor(0.813572, requires_grad=True), tensor(0.8116197, requires_grad=True), tensor(0.87729107, requires_grad=True), tensor(-0.14341337, requires_grad=True), tensor(0.02435672, requires_grad=True), tensor(0.89237947, requires_grad=True), tensor(0.89249343, requires_grad=True), tensor(0.8264586, requires_grad=True), tensor(0.89825611, requires_grad=True), tensor(-0.11985065, requires_grad=True), tensor(-0.00625288, requires_grad=True), tensor(-0.08280425, requires_grad=True), tensor(0.86397606, requires_grad=True), tensor(-0.06202649, requires_grad=True), tensor(0.04100685, requires_grad=True), tensor(0.04400209, requires_grad=True), tensor(0.88511769, requires_grad=True), tensor(0.08617398, requires_grad=True), tensor(0.00618166, requires_grad=True), tensor(0.86821376, requires_grad=True), tensor(0.81922058, requires_grad=True), tensor(0.85178255, requires_grad=True), tensor(0.86546361, requires_grad=True), tensor(0.84314753, requires_grad=True), tensor(0.31482264, requires_grad=True), tensor(0.84348066, requires_grad=True), tensor(0.87257158, requires_grad=True), tensor(0.53842224, requires_grad=True), tensor(0.6765435, requires_grad=True), tensor(-0.1028311, requires_grad=True), tensor(-0.12780886, requires_grad=True), tensor(0.83621273, requires_grad=True), tensor(0.86846553, requires_grad=True), tensor(-0.02164467, requires_grad=True), tensor(0.85203569, requires_grad=True), tensor(0.60560536, requires_grad=True), tensor(0.7855403, requires_grad=True), tensor(-0.10882255, requires_grad=True), tensor(0.91958887, requires_grad=True), tensor(0.83977698, requires_grad=True), tensor(0.87551218, requires_grad=True), tensor(-0.18334257, requires_grad=True), tensor(0.86092557, requires_grad=True), tensor(0.85542238, requires_grad=True), tensor(0.01302964, requires_grad=True), tensor(0.03941093, requires_grad=True), tensor(-0.11421272, requires_gr ...
